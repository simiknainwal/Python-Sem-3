# %%
import pandas as pd
df=pd.read_csv("student_data.csv")
df.shape
# Out:
# (32, 8)

# %%
df["University"]="Graphic Era"
df.head()
# Out:
#    Roll No.     Name  Semester Section  SGPA  CGPA  Attendance (%)  \
# 0         1   Harsha         3       D  8.57  6.33              92
# 1         2   Harini         3       C  6.65  7.93              89
# 2         3   Rakesh         3       D  6.81  8.95              94
# 3         4   Nikhil         3       C  8.12  7.02              83
# 4         5  Anirudh         3       B  8.65  6.00              78
#
#   Internship Status   University
# 0           Ongoing  Graphic Era
# 1         Completed  Graphic Era
# 2       Not Started  Graphic Era
# 3       Not Started  Graphic Era
# 4         Completed  Graphic Era

# %%
df.rename(columns={"Attendance (%)":"Attendance_per"},inplace=True)
# df1=df.rename(columns={"Attendance (%)":"Attendance_per"}) #stores the table in df1.
df.head()
# Out:
#    Roll No.     Name  Semester Section  SGPA  CGPA  Attendance_per  \
# 0         1   Harsha         3       D  8.57  6.33              92
# 1         2   Harini         3       C  6.65  7.93              89
# 2         3   Rakesh         3       D  6.81  8.95              94
# 3         4   Nikhil         3       C  8.12  7.02              83
# 4         5  Anirudh         3       B  8.65  6.00              78
#
#   Internship Status   University
# 0           Ongoing  Graphic Era
# 1         Completed  Graphic Era
# 2       Not Started  Graphic Era
# 3       Not Started  Graphic Era
# 4         Completed  Graphic Era

# %%
df["Debarred"]=df["Attendance_per"].apply(lambda x:"No" if x>80 else "Yes")
df.head()
# Out:
#    Roll No.     Name  Semester Section  SGPA  CGPA  Attendance_per  \
# 0         1   Harsha         3       D  8.57  6.33              92
# 1         2   Harini         3       C  6.65  7.93              89
# 2         3   Rakesh         3       D  6.81  8.95              94
# 3         4   Nikhil         3       C  8.12  7.02              83
# 4         5  Anirudh         3       B  8.65  6.00              78
#
#   Internship Status   University Debarred
# 0           Ongoing  Graphic Era       No
# 1         Completed  Graphic Era       No
# 2       Not Started  Graphic Era       No
# 3       Not Started  Graphic Era       No
# 4         Completed  Graphic Era      Yes

# %%
df["Attendance_per"]=df["Attendance_per"].apply(lambda x: x+5)
df.head()
# Out:
#    Roll No.     Name  Semester Section  SGPA  CGPA  Attendance_per  \
# 0         1   Harsha         3       D  8.57  6.33             102
# 1         2   Harini         3       C  6.65  7.93              99
# 2         3   Rakesh         3       D  6.81  8.95             104
# 3         4   Nikhil         3       C  8.12  7.02              93
# 4         5  Anirudh         3       B  8.65  6.00              88
#
#   Internship Status   University Debarred
# 0           Ongoing  Graphic Era       No
# 1         Completed  Graphic Era       No
# 2       Not Started  Graphic Era       No
# 3       Not Started  Graphic Era       No
# 4         Completed  Graphic Era      Yes

# %%
# df.drop("Attendance_per",axis=1,inplace=True)
df.drop("Internship Status",axis=1)
# df.head()
# Out:
#    Roll No.     Name  Semester Section  SGPA  CGPA  Attendance_per  \
# 0         1   Harsha         3       D  8.57  6.33             102
# 1         2   Harini         3       C  6.65  7.93              99
# 2         3   Rakesh         3       D  6.81  8.95             104
# 3         4   Nikhil         3       C  8.12  7.02              93
# 4         5  Anirudh         3       B  8.65  6.00              88
#
#   Internship Status   University Debarred
# 0           Ongoing  Graphic Era       No
# 1         Completed  Graphic Era       No
# 2       Not Started  Graphic Era       No
# 3       Not Started  Graphic Era       No
# 4         Completed  Graphic Era      Yes
