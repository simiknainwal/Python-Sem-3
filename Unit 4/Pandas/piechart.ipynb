# %%
import matplotlib.pyplot as plt

# %%
students=[36,28,39,17]
sections=['A','B','C','D']
explode=[0,0,0.1,0]
plt.pie(students,labels=sections,autopct="%1.1f%%",explode=explode,shadow=True,counterclock=False,startangle=90, wedgeprops={"linewidth":2})
plt.show()
